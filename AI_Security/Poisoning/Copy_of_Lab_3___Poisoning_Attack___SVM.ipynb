# %% [markdown]
# # Poisoning Attack against SVM
#
# In this tutorial, we will create poisoned data, which declines the performance of the model when the poisoned data is injected into the training dataset.

# %% [markdown]
# ![lab3.webp](data:image/webp;base64,...)

# %% [markdown]
# # Shell installs (enviroment setup)

# %%
# !apt install -y libboost-all-dev
# !pip install -U pip
# !pip install "pybind11[global]"

# !pip install aijack
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   javascript-common libboost-atomic-dev libboost-container-dev
#   libboost-container1.74-dev libboost-container1.74.0 libboost-context-dev
#   libboost-context1.74-dev libboost-context1.74.0 libboost-coroutine-dev
#   libboost-coroutine1.74-dev libboost-coroutine1.74.0 libboost-exception-dev
#   libboost-exception1.74-dev libboost-fiber-dev libboost-fiber1.74-dev
#   libboost-fiber1.74.0 libboost-graph-dev libboost-graph-parallel-dev
#   libboost-graph-parallel1.74-dev libboost-graph-parallel1.74.0
#   libboost-graph1.74-dev libboost-graph1.74.0 libboost-locale-dev
#   libboost-locale1.74-dev libboost-locale1.74.0 libboost-mpi-dev
#   libboost-mpi-python-dev libboost-mpi-python1.74-dev
#   libboost-mpi-python1.74.0 libboost-mpi1.74-dev libboost-mpi1.74.0
#   libboost-nowide-dev libboost-nowide1.74-dev libboost-nowide1.74.0
#   libboost-numpy-dev libboost-numpy1.74-dev libboost-numpy1.74.0
#   libboost-python-dev libboost-python1.74-dev libboost-python1.74.0
#   libboost-stacktrace-dev libboost-stacktrace1.74-dev
#   libboost-stacktrace1.74.0 libboost-test-dev libboost-test1.74-dev
#   libboost-test1.74.0 libboost-timer-dev libboost-timer1.74-dev
#   libboost-timer1.74.0 libboost-tools-dev libboost-type-erasure-dev
#   libboost-type-erasure1.74-dev libboost-type-erasure1.74.0 libboost-wave-dev
#   libboost-wave1.74-dev libboost-wave1.74.0 libboost1.74-tools-dev
#   libjs-sphinxdoc libjs-underscore libpython3.10 libpython3.10-dev
#   libpython3.10-minimal libpython3.10-stdlib python3-dev python3.10
#   python3.10-dev python3.10-minimal
# Suggested packages:
#   apache2 | lighttpd | httpd libboost1.74-doc gccxml xsltproc doxygen
#   docbook-xml docbook-xsl default-jdk fop python3.10-venv python3.10-doc
#   binfmt-support
# The following NEW packages will be installed:
#   javascript-common libboost-all-dev libboost-atomic-dev
#   libboost-container-dev libboost-container1.74-dev libboost-container1.74.0
#   libboost-context-dev libboost-context1.74-dev libboost-context1.74.0
#   libboost-coroutine-dev libboost-coroutine1.74-dev libboost-coroutine1.74.0
#   libboost-exception-dev libboost-exception1.74-dev libboost-fiber-dev
#   libboost-fiber1.74-dev libboost-fiber1.74.0 libboost-graph-dev
#   libboost-graph-parallel-dev libboost-graph-parallel1.74-dev
#   libboost-graph-parallel1.74.0 libboost-graph1.74-dev libboost-graph1.74.0
#   libboost-locale-dev libboost-locale1.74-dev libboost-locale1.74.0
#   libboost-mpi-dev libboost-mpi-python-dev libboost-mpi-python1.74-dev
#   libboost-mpi-python1.74.0 libboost-mpi1.74-dev libboost-mpi1.74.0
#   libboost-nowide-dev libboost-nowide1.74-dev libboost-nowide1.74.0
#   libboost-numpy-dev libboost-numpy1.74-dev libboost-numpy1.74.0
#   libboost-python-dev libboost-python1.74-dev libboost-python1.74.0
#   libboost-stacktrace-dev libboost-stacktrace1.74-dev
#   libboost-stacktrace1.74.0 libboost-test-dev libboost-test1.74-dev
#   libboost-test1.74.0 libboost-timer-dev libboost-timer1.74-dev
#   libboost-timer1.74.0 libboost-tools-dev libboost-type-erasure-dev
#   libboost-type-erasure1.74-dev libboost-type-erasure1.74.0 libboost-wave-dev
#   libboost-wave1.74-dev libboost-wave1.74.0 libboost1.74-tools-dev
#   libjs-sphinxdoc libjs-underscore python3-dev python3.10-dev
# The following packages will be upgraded:
#   libpython3.10 libpython3.10-dev libpython3.10-minimal libpython3.10-stdlib
#   python3.10 python3.10-minimal
# 6 upgraded, 62 newly installed, 0 to remove and 98 not upgraded.
# Need to get 24.7 MB of archives.
# After this operation, 102 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpython3.10-dev amd64 3.10.12-1~22.04.14 [4,765 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpython3.10 amd64 3.10.12-1~22.04.14 [1,949 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3.10 amd64 3.10.12-1~22.04.14 [509 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpython3.10-stdlib amd64 3.10.12-1~22.04.14 [1,850 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3.10-minimal amd64 3.10.12-1~22.04.14 [2,275 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpython3.10-minimal amd64 3.10.12-1~22.04.14 [816 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 javascript-common all 11+nmu1 [5,936 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost1.74-tools-dev amd64 1.74.0-14ubuntu3 [1,351 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-tools-dev amd64 1.74.0.3ubuntu7 [3,428 B]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-atomic-dev amd64 1.74.0.3ubuntu7 [3,544 B]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-container1.74.0 amd64 1.74.0-14ubuntu3 [246 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-container1.74-dev amd64 1.74.0-14ubuntu3 [254 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-container-dev amd64 1.74.0.3ubuntu7 [3,712 B]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-context1.74.0 amd64 1.74.0-14ubuntu3 [223 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-context1.74-dev amd64 1.74.0-14ubuntu3 [220 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-context-dev amd64 1.74.0.3ubuntu7 [3,456 B]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-coroutine1.74.0 amd64 1.74.0-14ubuntu3 [235 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-coroutine1.74-dev amd64 1.74.0-14ubuntu3 [244 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-coroutine-dev amd64 1.74.0.3ubuntu7 [3,520 B]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-exception1.74-dev amd64 1.74.0-14ubuntu3 [217 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-exception-dev amd64 1.74.0.3ubuntu7 [3,250 B]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-fiber1.74.0 amd64 1.74.0-14ubuntu3 [242 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-fiber1.74-dev amd64 1.74.0-14ubuntu3 [254 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-fiber-dev amd64 1.74.0.3ubuntu7 [3,674 B]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-graph1.74.0 amd64 1.74.0-14ubuntu3 [304 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-test1.74.0 amd64 1.74.0-14ubuntu3 [446 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-test1.74-dev amd64 1.74.0-14ubuntu3 [564 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-graph1.74-dev amd64 1.74.0-14ubuntu3 [335 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-graph-dev amd64 1.74.0.3ubuntu7 [3,348 B]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-mpi1.74.0 amd64 1.74.0-14ubuntu3 [259 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-graph-parallel1.74.0 amd64 1.74.0-14ubuntu3 [266 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-graph-parallel1.74-dev amd64 1.74.0-14ubuntu3 [277 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-graph-parallel-dev amd64 1.74.0.3ubuntu7 [3,384 B]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-locale1.74.0 amd64 1.74.0-14ubuntu3 [413 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-locale1.74-dev amd64 1.74.0-14ubuntu3 [594 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-locale-dev amd64 1.74.0.3ubuntu7 [3,572 B]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-mpi1.74-dev amd64 1.74.0-14ubuntu3 [285 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-mpi-dev amd64 1.74.0.3ubuntu7 [3,328 B]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/main amd64 libboost-python1.74.0 amd64 1.74.0-14ubuntu3 [299 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-mpi-python1.74.0 amd64 1.74.0-14ubuntu3 [351 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-mpi-python1.74-dev amd64 1.74.0-14ubuntu3 [225 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-mpi-python-dev amd64 1.74.0.3ubuntu7 [3,382 B]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-numpy1.74.0 amd64 1.74.0-14ubuntu3 [229 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-numpy1.74-dev amd64 1.74.0-14ubuntu3 [233 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-numpy-dev amd64 1.74.0.3ubuntu7 [3,286 B]
# Get:46 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3.10-dev amd64 3.10.12-1~22.04.14 [508 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjs-underscore all 1.13.2~dfsg-2 [118 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjs-sphinxdoc all 4.3.2-1 [139 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 python3-dev amd64 3.10.6-1~22.04.1 [26.0 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-python1.74-dev amd64 1.74.0-14ubuntu3 [323 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-python-dev amd64 1.74.0.3ubuntu7 [3,538 B]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-stacktrace1.74.0 amd64 1.74.0-14ubuntu3 [267 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-stacktrace1.74-dev amd64 1.74.0-14ubuntu3 [232 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-stacktrace-dev amd64 1.74.0.3ubuntu7 [3,260 B]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-test-dev amd64 1.74.0.3ubuntu7 [3,274 B]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-timer1.74.0 amd64 1.74.0-14ubuntu3 [228 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-timer1.74-dev amd64 1.74.0-14ubuntu3 [231 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-timer-dev amd64 1.74.0.3ubuntu7 [3,380 B]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-type-erasure1.74.0 amd64 1.74.0-14ubuntu3 [234 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-type-erasure1.74-dev amd64 1.74.0-14ubuntu3 [239 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-type-erasure-dev amd64 1.74.0.3ubuntu7 [3,344 B]
# Get:62 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-wave1.74.0 amd64 1.74.0-14ubuntu3 [449 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-wave1.74-dev amd64 1.74.0-14ubuntu3 [496 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-wave-dev amd64 1.74.0.3ubuntu7 [3,292 B]
# Get:65 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-nowide1.74.0 amd64 1.74.0-14ubuntu3 [223 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-nowide1.74-dev amd64 1.74.0-14ubuntu3 [220 kB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-nowide-dev amd64 1.74.0.3ubuntu7 [3,322 B]
# Get:68 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libboost-all-dev amd64 1.74.0.3ubuntu7 [2,268 B]
# Fetched 24.7 MB in 2s (12.0 MB/s)
# Extracting templates from packages: 100%
# (Reading database ... 117856 files and directories currently installed.)
# Preparing to unpack .../00-libpython3.10-dev_3.10.12-1~22.04.14_amd64.deb ...
# Unpacking libpython3.10-dev:amd64 (3.10.12-1~22.04.14) over (3.10.12-1~22.04.13) ...
# Preparing to unpack .../01-libpython3.10_3.10.12-1~22.04.14_amd64.deb ...
# Unpacking libpython3.10:amd64 (3.10.12-1~22.04.14) over (3.10.12-1~22.04.13) ...
# Preparing to unpack .../02-python3.10_3.10.12-1~22.04.14_amd64.deb ...
# Unpacking python3.10 (3.10.12-1~22.04.14) over (3.10.12-1~22.04.13) ...
# Preparing to unpack .../03-libpython3.10-stdlib_3.10.12-1~22.04.14_amd64.deb ...
# Unpacking libpython3.10-stdlib:amd64 (3.10.12-1~22.04.14) over (3.10.12-1~22.04.13) ...
# Preparing to unpack .../04-python3.10-minimal_3.10.12-1~22.04.14_amd64.deb ...
# Unpacking python3.10-minimal (3.10.12-1~22.04.14) over (3.10.12-1~22.04.13) ...
# Preparing to unpack .../05-libpython3.10-minimal_3.10.12-1~22.04.14_amd64.deb ...
# Unpacking libpython3.10-minimal:amd64 (3.10.12-1~22.04.14) over (3.10.12-1~22.04.13) ...
# Selecting previously unselected package javascript-common.
# Preparing to unpack .../06-javascript-common_11+nmu1_all.deb ...
# Unpacking javascript-common (11+nmu1) ...
# Selecting previously unselected package libboost1.74-tools-dev.
# Preparing to unpack .../07-libboost1.74-tools-dev_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost1.74-tools-dev (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-tools-dev.
# Preparing to unpack .../08-libboost-tools-dev_1.74.0.3ubuntu7_amd64.deb ...
# Unpacking libboost-tools-dev (1.74.0.3ubuntu7) ...
# Selecting previously unselected package libboost-atomic-dev:amd64.
# Preparing to unpack .../09-libboost-atomic-dev_1.74.0.3ubuntu7_amd64.deb ...
# Unpacking libboost-atomic-dev:amd64 (1.74.0.3ubuntu7) ...
# Selecting previously unselected package libboost-container1.74.0:amd64.
# Preparing to unpack .../10-libboost-container1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-container1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-container1.74-dev:amd64.
# Preparing to unpack .../11-libboost-container1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-container1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-container-dev:amd64.
# Preparing to unpack .../12-libboost-container-dev_1.74.0.3ubuntu7_amd64.deb ...
# Unpacking libboost-container-dev:amd64 (1.74.0.3ubuntu7) ...
# Selecting previously unselected package libboost-context1.74.0:amd64.
# Preparing to unpack .../13-libboost-context1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-context1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-context1.74-dev:amd64.
# Preparing to unpack .../14-libboost-context1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-context1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-context-dev:amd64.
# Preparing to unpack .../15-libboost-context-dev_1.74.0.3ubuntu7_amd64.deb ...
# Unpacking libboost-context-dev:amd64 (1.74.0.3ubuntu7) ...
# Selecting previously unselected package libboost-coroutine1.74.0:amd64.
# Preparing to unpack .../16-libboost-coroutine1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-coroutine1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-coroutine1.74-dev:amd64.
# Preparing to unpack .../17-libboost-coroutine1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-coroutine1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-coroutine-dev:amd64.
# Preparing to unpack .../18-libboost-coroutine-dev_1.74.0.3ubuntu7_amd64.deb ...
# Unpacking libboost-coroutine-dev:amd64 (1.74.0.3ubuntu7) ...
# Selecting previously unselected package libboost-exception1.74-dev:amd64.
# Preparing to unpack .../19-libboost-exception1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-exception1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-exception-dev:amd64.
# Preparing to unpack .../20-libboost-exception-dev_1.74.0.3ubuntu7_amd64.deb ...
# Unpacking libboost-exception-dev:amd64 (1.74.0.3ubuntu7) ...
# Selecting previously unselected package libboost-fiber1.74.0:amd64.
# Preparing to unpack .../21-libboost-fiber1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-fiber1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-fiber1.74-dev:amd64.
# Preparing to unpack .../22-libboost-fiber1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-fiber1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-fiber-dev:amd64.
# Preparing to unpack .../23-libboost-fiber-dev_1.74.0.3ubuntu7_amd64.deb ...
# Unpacking libboost-fiber-dev:amd64 (1.74.0.3ubuntu7) ...
# Selecting previously unselected package libboost-graph1.74.0:amd64.
# Preparing to unpack .../24-libboost-graph1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-graph1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-test1.74.0:amd64.
# Preparing to unpack .../25-libboost-test1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-test1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-test1.74-dev:amd64.
# Preparing to unpack .../26-libboost-test1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-test1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-graph1.74-dev:amd64.
# Preparing to unpack .../27-libboost-graph1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-graph1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-graph-dev:amd64.
# Preparing to unpack .../28-libboost-graph-dev_1.74.0.3ubuntu7_amd64.deb ...
# Unpacking libboost-graph-dev:amd64 (1.74.0.3ubuntu7) ...
# Selecting previously unselected package libboost-mpi1.74.0.
# Preparing to unpack .../29-libboost-mpi1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-mpi1.74.0 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-graph-parallel1.74.0.
# Preparing to unpack .../30-libboost-graph-parallel1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-graph-parallel1.74.0 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-graph-parallel1.74-dev.
# Preparing to unpack .../31-libboost-graph-parallel1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-graph-parallel1.74-dev (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-graph-parallel-dev.
# Preparing to unpack .../32-libboost-graph-parallel-dev_1.74.0.3ubuntu7_amd64.deb ...
# Unpacking libboost-graph-parallel-dev (1.74.0.3ubuntu7) ...
# Selecting previously unselected package libboost-locale1.74.0:amd64.
# Preparing to unpack .../33-libboost-locale1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-locale1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-locale1.74-dev:amd64.
# Preparing to unpack .../34-libboost-locale1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-locale1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-locale-dev:amd64.
# Preparing to unpack .../35-libboost-locale-dev_1.74.0.3ubuntu7_amd64.deb ...
# Unpacking libboost-locale-dev:amd64 (1.74.0.3ubuntu7) ...
# Selecting previously unselected package libboost-mpi1.74-dev.
# Preparing to unpack .../36-libboost-mpi1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-mpi1.74-dev (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-mpi-dev.
# Preparing to unpack .../37-libboost-mpi-dev_1.74.0.3ubuntu7_amd64.deb ...
# Unpacking libboost-mpi-dev (1.74.0.3ubuntu7) ...
# Selecting previously unselected package libboost-python1.74.0.
# Preparing to unpack .../38-libboost-python1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-python1.74.0 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-mpi-python1.74.0.
# Preparing to unpack .../39-libboost-mpi-python1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-mpi-python1.74.0 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-mpi-python1.74-dev.
# Preparing to unpack .../40-libboost-mpi-python1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-mpi-python1.74-dev (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-mpi-python-dev.
# Preparing to unpack .../41-libboost-mpi-python-dev_1.74.0.3ubuntu7_amd64.deb ...
# Unpacking libboost-mpi-python-dev (1.74.0.3ubuntu7) ...
# Selecting previously unselected package libboost-numpy1.74.0.
# Preparing to unpack .../42-libboost-numpy1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-numpy1.74.0 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-numpy1.74-dev.
# Preparing to unpack .../43-libboost-numpy1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-numpy1.74-dev (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-numpy-dev.
# Preparing to unpack .../44-libboost-numpy-dev_1.74.0.3ubuntu7_amd64.deb ...
# Unpacking libboost-numpy-dev (1.74.0.3ubuntu7) ...
# Selecting previously unselected package python3.10-dev.
# Preparing to unpack .../45-python3.10-dev_3.10.12-1~22.04.14_amd64.deb ...
# Unpacking python3.10-dev (3.10.12-1~22.04.14) ...
# Selecting previously unselected package libjs-underscore.
# Preparing to unpack .../46-libjs-underscore_1.13.2~dfsg-2_all.deb ...
# Unpacking libjs-underscore (1.13.2~dfsg-2) ...
# Selecting previously unselected package libjs-sphinxdoc.
# Preparing to unpack .../47-libjs-sphinxdoc_4.3.2-1_all.deb ...
# Unpacking libjs-sphinxdoc (4.3.2-1) ...
# Selecting previously unselected package python3-dev.
# Preparing to unpack .../48-python3-dev_3.10.6-1~22.04.1_amd64.deb ...
# Unpacking python3-dev (3.10.6-1~22.04.1) ...
# Selecting previously unselected package libboost-python1.74-dev.
# Preparing to unpack .../49-libboost-python1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-python1.74-dev (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-python-dev.
# Preparing to unpack .../50-libboost-python-dev_1.74.0.3ubuntu7_amd64.deb ...
# Unpacking libboost-python-dev (1.74.0.3ubuntu7) ...
# Selecting previously unselected package libboost-stacktrace1.74.0:amd64.
# Preparing to unpack .../51-libboost-stacktrace1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-stacktrace1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-stacktrace1.74-dev:amd64.
# Preparing to unpack .../52-libboost-stacktrace1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-stacktrace1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-stacktrace-dev:amd64.
# Preparing to unpack .../53-libboost-stacktrace-dev_1.74.0.3ubuntu7_amd64.deb ...
# Unpacking libboost-stacktrace-dev:amd64 (1.74.0.3ubuntu7) ...
# Selecting previously unselected package libboost-test-dev:amd64.
# Preparing to unpack .../54-libboost-test-dev_1.74.0.3ubuntu7_amd64.deb ...
# Unpacking libboost-test-dev:amd64 (1.74.0.3ubuntu7) ...
# Selecting previously unselected package libboost-timer1.74.0:amd64.
# Preparing to unpack .../55-libboost-timer1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-timer1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-timer1.74-dev:amd64.
# Preparing to unpack .../56-libboost-timer1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-timer1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-timer-dev:amd64.
# Preparing to unpack .../57-libboost-timer-dev_1.74.0.3ubuntu7_amd64.deb ...
# Unpacking libboost-timer-dev:amd64 (1.74.0.3ubuntu7) ...
# Selecting previously unselected package libboost-type-erasure1.74.0:amd64.
# Preparing to unpack .../58-libboost-type-erasure1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-type-erasure1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-type-erasure1.74-dev:amd64.
# Preparing to unpack .../59-libboost-type-erasure1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-type-erasure1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-type-erasure-dev:amd64.
# Preparing to unpack .../60-libboost-type-erasure-dev_1.74.0.3ubuntu7_amd64.deb ...
# Unpacking libboost-type-erasure-dev:amd64 (1.74.0.3ubuntu7) ...
# Selecting previously unselected package libboost-wave1.74.0:amd64.
# Preparing to unpack .../61-libboost-wave1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-wave1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-wave1.74-dev:amd64.
# Preparing to unpack .../62-libboost-wave1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-wave1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-wave-dev:amd64.
# Preparing to unpack .../63-libboost-wave-dev_1.74.0.3ubuntu7_amd64.deb ...
# Unpacking libboost-wave-dev:amd64 (1.74.0.3ubuntu7) ...
# Selecting previously unselected package libboost-nowide1.74.0.
# Preparing to unpack .../64-libboost-nowide1.74.0_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-nowide1.74.0 (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-nowide1.74-dev.
# Preparing to unpack .../65-libboost-nowide1.74-dev_1.74.0-14ubuntu3_amd64.deb ...
# Unpacking libboost-nowide1.74-dev (1.74.0-14ubuntu3) ...
# Selecting previously unselected package libboost-nowide-dev.
# Preparing to unpack .../66-libboost-nowide-dev_1.74.0.3ubuntu7_amd64.deb ...
# Unpacking libboost-nowide-dev (1.74.0.3ubuntu7) ...
# Selecting previously unselected package libboost-all-dev.
# Preparing to unpack .../67-libboost-all-dev_1.74.0.3ubuntu7_amd64.deb ...
# Unpacking libboost-all-dev (1.74.0.3ubuntu7) ...
# Setting up javascript-common (11+nmu1) ...
# Setting up libboost-mpi1.74.0 (1.74.0-14ubuntu3) ...
# Setting up libboost-stacktrace1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Setting up libboost-nowide1.74.0 (1.74.0-14ubuntu3) ...
# Setting up libboost-exception1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# Setting up libboost-exception-dev:amd64 (1.74.0.3ubuntu7) ...
# Setting up libboost-test1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Setting up libboost-nowide1.74-dev (1.74.0-14ubuntu3) ...
# Setting up libboost-context1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Setting up libboost-graph1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Setting up libpython3.10-minimal:amd64 (3.10.12-1~22.04.14) ...
# Setting up libboost1.74-tools-dev (1.74.0-14ubuntu3) ...
# Setting up libboost-wave1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Setting up libboost-atomic-dev:amd64 (1.74.0.3ubuntu7) ...
# Setting up libboost-container1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Setting up libboost-graph-parallel1.74.0 (1.74.0-14ubuntu3) ...
# Setting up libboost-python1.74.0 (1.74.0-14ubuntu3) ...
# Setting up libboost-fiber1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Setting up libboost-locale1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Setting up libboost-stacktrace1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# Setting up libboost-test1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# Setting up libboost-timer1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Setting up libboost-type-erasure1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Setting up libjs-underscore (1.13.2~dfsg-2) ...
# Setting up libboost-numpy1.74.0 (1.74.0-14ubuntu3) ...
# Setting up libboost-mpi-python1.74.0 (1.74.0-14ubuntu3) ...
# Setting up libboost-wave1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# Setting up libboost-mpi1.74-dev (1.74.0-14ubuntu3) ...
# Setting up libboost-container1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# Setting up libboost-coroutine1.74.0:amd64 (1.74.0-14ubuntu3) ...
# Setting up libboost-mpi-python1.74-dev (1.74.0-14ubuntu3) ...
# Setting up libboost-tools-dev (1.74.0.3ubuntu7) ...
# Setting up libboost-wave-dev:amd64 (1.74.0.3ubuntu7) ...
# Setting up libboost-nowide-dev (1.74.0.3ubuntu7) ...
# Setting up python3.10-minimal (3.10.12-1~22.04.14) ...
# Setting up libboost-context1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# Setting up libboost-container-dev:amd64 (1.74.0.3ubuntu7) ...
# Setting up libboost-test-dev:amd64 (1.74.0.3ubuntu7) ...
# Setting up libpython3.10-stdlib:amd64 (3.10.12-1~22.04.14) ...
# Setting up libboost-fiber1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# Setting up libboost-mpi-python-dev (1.74.0.3ubuntu7) ...
# Setting up libboost-type-erasure1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# Setting up libboost-mpi-dev (1.74.0.3ubuntu7) ...
# Setting up libboost-graph1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# Setting up libboost-timer1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# Setting up libboost-numpy1.74-dev (1.74.0-14ubuntu3) ...
# Setting up libboost-locale1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# Setting up libboost-graph-parallel1.74-dev (1.74.0-14ubuntu3) ...
# Setting up libjs-sphinxdoc (4.3.2-1) ...
# Setting up libboost-stacktrace-dev:amd64 (1.74.0.3ubuntu7) ...
# Setting up libboost-coroutine1.74-dev:amd64 (1.74.0-14ubuntu3) ...
# Setting up libboost-coroutine-dev:amd64 (1.74.0.3ubuntu7) ...
# Setting up libboost-timer-dev:amd64 (1.74.0.3ubuntu7) ...
# Setting up libboost-fiber-dev:amd64 (1.74.0.3ubuntu7) ...
# Setting up libboost-graph-dev:amd64 (1.74.0.3ubuntu7) ...
# Setting up libpython3.10:amd64 (3.10.12-1~22.04.14) ...
# Setting up python3.10 (3.10.12-1~22.04.14) ...
# Setting up libboost-locale-dev:amd64 (1.74.0.3ubuntu7) ...
# Setting up libboost-context-dev:amd64 (1.74.0.3ubuntu7) ...
# Setting up libboost-type-erasure-dev:amd64 (1.74.0.3ubuntu7) ...
# Setting up libboost-numpy-dev (1.74.0.3ubuntu7) ...
# Setting up libpython3.10-dev:amd64 (3.10.12-1~22.04.14) ...
# Setting up libboost-graph-parallel-dev (1.74.0.3ubuntu7) ...
# Setting up python3.10-dev (3.10.12-1~22.04.14) ...
# Setting up python3-dev (3.10.6-1~22.04.1) ...
# Setting up libboost-python1.74-dev (1.74.0-14ubuntu3) ...
# Setting up libboost-python-dev (1.74.0.3ubuntu7) ...
# Setting up libboost-all-dev (1.74.0.3ubuntu7) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.11) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-26.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 38.1 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-26.0.1
# Collecting pybind11[global]
#   Using cached pybind11-3.0.2-py3-none-any.whl.metadata (10 kB)
# Collecting pybind11-global==3.0.2 (from pybind11[global])
#   Using cached pybind11_global-3.0.2-py3-none-any.whl.metadata (10 kB)
# Using cached pybind11-3.0.2-py3-none-any.whl (310 kB)
# Using cached pybind11_global-3.0.2-py3-none-any.whl (572 kB)
# Installing collected packages: pybind11-global, pybind11
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pybind11]
# Successfully installed pybind11-3.0.2 pybind11-global-3.0.2
# Collecting aijack
#   Using cached aijack-0.0.1b2.tar.gz (142 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from aijack) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from aijack) (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from aijack) (1.6.1)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from aijack) (2.10.0+cpu)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from aijack) (0.25.0+cpu)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (from aijack) (4.13.0.92)
# Requirement already satisfied: pybind11 in /usr/local/lib/python3.12/dist-packages (from aijack) (3.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from aijack) (3.10.0)
# Collecting mpi4py (from aijack)
#   Using cached mpi4py-4.1.1-cp312-cp312-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.12/dist-packages (from aijack) (0.14.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->aijack) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->aijack) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->aijack) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->aijack) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->aijack) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->aijack) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.11.0->aijack) (2025.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.11.0->aijack) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.11.0->aijack) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->aijack) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->aijack) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->aijack) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->aijack) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->aijack) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->aijack) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->aijack) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->aijack) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->aijack) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->aijack) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->aijack) (2025.3)
# Requirement already satisfied: pybind11-global==3.0.2 in /usr/local/lib/python3.12/dist-packages (from pybind11[global]->aijack) (3.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->aijack) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->aijack) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->aijack) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels->aijack) (1.0.2)
# Using cached mpi4py-4.1.1-cp312-cp312-manylinux1_x86_64.manylinux_2_5_x86_64.whl (1.4 MB)
# Building wheels for collected packages: aijack
#   Building wheel for aijack (pyproject.toml) ... done
#   Created wheel for aijack: filename=aijack-0.0.1b2-cp312-cp312-linux_x86_64.whl size=596614 sha256=e507fe27e8aa240274ab6f1dfafe613bf635e56f5ae93b8d4ef714d7fd09776e
#   Stored in directory: /root/.cache/pip/wheels/b4/e7/c3/a6eb8c4eec13529aeea08fe3c4cd0c526feb442e4a5fd41f85
# Successfully built aijack
# Installing collected packages: mpi4py, aijack
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [aijack]
# Successfully installed aijack-0.0.1b2 mpi4py-4.1.1

# %%
# !apt-get update -qq
# !apt-get install -y --fix-missing \
  libboost-filesystem-dev libboost-system-dev libboost-thread-dev \
  libboost-serialization-dev libboost-regex-dev libboost-program-options-dev \
  libboost-date-time-dev libboost-iostreams-dev libboost-log-dev \
  libboost-random-dev libboost-math-dev libboost-chrono-dev

# !pip install aijack

# If !pip install aijack still fails, run this to see the full error:
# !pip install aijack -v 2>&1 | tail -60

# %% [markdown]
# # Imports

# %%
import os
import time
import copy
import random
from tqdm import tqdm

import numpy as np

import sklearn
from sklearn import datasets
from sklearn import metrics
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt

from aijack.attack import Poison_attack_sklearn

# %%
np.random.seed(77)
random.seed(77)

# %% [markdown]
# # Prepare Dataset

# %%
mnist = datasets.fetch_openml("mnist_784", version=1, data_home=".", return_X_y=True)
imagedata, labeldata = mnist[0].values, mnist[1].values

index_3 = [i for i, x in enumerate(labeldata) if x == "3"]
index_7 = [i for i, x in enumerate(labeldata) if x == "7"]
image_data_3_7 = imagedata[index_3 + index_7]
label_data_3_7 = labeldata[index_3 + index_7]

(
    imagedata_training,
    imagedata_validation,
    labeldata_training,
    labeldata_validation,
) = train_test_split(image_data_3_7, label_data_3_7, test_size=0.2, shuffle=True)

imagedata_training = imagedata_training / 255.0
imagedata_validation = imagedata_validation / 255.0

X_train = imagedata_training[:5000]
y_train = labeldata_training[:5000]
X_valid = imagedata_validation[:500]
y_valid = labeldata_validation[:500]

# %% [markdown]
# # Train the target classification model

# %%
clf = SVC(kernel="linear")
clf.fit(X_train, y_train)

predict = clf.predict(X_valid)

ac_score = metrics.accuracy_score(y_valid, predict)
cl_report = metrics.classification_report(y_valid, predict)
print(cl_report)
# Out:
#               precision    recall  f1-score   support
#
#            3       0.99      0.97      0.98       229
#            7       0.98      0.99      0.99       271
#
#     accuracy                           0.98       500
#    macro avg       0.98      0.98      0.98       500
# weighted avg       0.98      0.98      0.98       500

# %% [markdown]
# # Poisoning Attack
#
# We pick one training image and add poisoning noise to it.

# %%
# initial point
initial_idx = np.where(y_train == "7")[0][42]
xc = copy.deepcopy(X_train[initial_idx, :])
yc = y_train[initial_idx]

train_idx = random.sample(list(range(1, X_train.shape[0])), 100)
X_train_ = copy.copy(X_train[train_idx, :])
y_train_ = copy.copy(y_train[train_idx])
y_train_ = np.where(y_train_ == "7", 1, -1)
y_valid_ = np.where(y_valid == "7", 1, -1)

plt.figure(figsize=(1, 1))
plt.imshow(xc.reshape(28, 28), cmap="gray")
plt.axis("off")
plt.show()

# %% [markdown]
# You can execute poison attack with only one line.

# %%
attacker = Poison_attack_sklearn(clf, X_train_, y_train_, t=0.5)
xc_attacked, log = attacker.attack(xc, 1, X_valid, y_valid_, num_iterations=200)

# %% [markdown]
# Graph of attack progress and the noised image

# %%
plt.plot(log)
plt.xlabel("Iteration")
plt.ylabel("Accuracy")
plt.title("Attack Progress")
plt.show()

#The noised image looks as follows.
plt.figure(figsize=(1, 1))
plt.imshow(xc_attacked.reshape(28, 28), cmap="gray")
plt.axis("off")
plt.show()

# %% [markdown]
# ## Performance of Pisoned Model

# %%
clf = SVC(kernel="linear", C=1)
clf.fit(X_train_, y_train_)
print("before attack: ", clf.score(X_valid, y_valid_))

# add poinsoned data
clf = SVC(kernel="linear", C=1)
clf.fit(
    np.concatenate([X_train_, xc_attacked.reshape(1, -1)]),
    np.concatenate([y_train_, [-1]]),
)
print("after attack: ", clf.score(X_valid, y_valid_))
# Out:
# before attack:  0.956
# after attack:  0.846
